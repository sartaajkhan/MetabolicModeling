# %% [markdown]
# # Sensitivity to minimum productivity constraints #
#
# ### File to generate Fig S7 ###

# %%
import numpy as np
import cameo
import pandas as pd
from copy import deepcopy
import pickle
import time
import multiprocessing
from joblib import Parallel, delayed
from mcpecaso.plotting import multiplot_envelopes,plot_envelope,plot_pecaso_dfba,\
                              multi_two_stage_char_contours,two_stage_char_contour
from mcpecaso.core import mcPECASO
import mcpecaso as mcpecaso

mcpecaso.settings.time_end = 100
mcpecaso.settings.initial_biomass = 0.05
mcpecaso.settings.initial_substrate = 500
mcpecaso.settings.num_timepoints = 10000
mcpecaso.settings.scope = 'extrema'

num_cores = multiprocessing.cpu_count()
model = cameo.models.bigg.iJO1366
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Academic license - for non-commercial use only

# %%
metabolite_names_dict = {'Spermidine': 'Spermidine',
                         'L-Tryptophan': 'L-Tryptophan',
                         'Thymidine C10H14N2O5': 'Thymidine',
                         'L-Phenylalanine': 'L-Phenylalanine',
                         'Adenosine': 'Adenosine',
                         'Indole': 'Indole',
                         'L-Tyrosine': 'L-Tyrosine',
                         'Inosine': 'Inosine',
                         'Xanthosine': 'Xanthosine',
                         'Cytidine': 'Cytidine',
                         'Uridine': 'Uridine',
                         'Quinate': 'Quinate',
                         'L-Isoleucine': 'L-Isoleucine',
                         'L-Lysine': 'L-Lysine',
                         'Hexanoate (n-C6:0)': 'Hexanoate',
                         'L-Leucine': 'L-Leucine',
                         'L-Arginine': 'L-Arginine',
                         'L-Histidine': 'L-Histidine',
                         'D-Gluconate': 'D-Gluconic Acid',
                         'L-Idonate': 'L-Idonic Acid',
                         '5-Dehydro-D-gluconate': '5-Ketogluconate',
                         'Citrate': 'Citric Acid',
                         'Agmatine': 'Agmatine',
                         'Ornithine': 'Ornithine',
                         'L-Proline': 'L-Proline',
                         'L-Valine': 'L-Valine',
                         'Thymine C5H6N2O2': 'Thymine',
                         'Adenine': 'Adenine',
                         'Guanine': 'Guanine',
                         'Hypoxanthine': 'Hypoxanthine',
                         'O-Acetyl-L-serine': 'O-Acetyl-L-serine',
                         'Xanthine': 'Xanthine',
                         'L-Glutamate': 'L-Glutamate',
                         '2-Oxoglutarate': '\u03b1-Ketoglutarate',
                         'Putrescine': 'Putrescine',
                         'L-Threonine': 'L-Threonine',
                         '4-Aminobutanoate': '\u03b3-Aminobutyrate',
                         'L-Homoserine': 'L-Homoserine',
                         'Allantoin': 'Allantoin',
                         'Succinate': 'Succinate',
                         'Uracil': 'Uracil',
                         'L-Asparagine': 'L-Asparagine',
                         'L-Malate': 'L-Malate',
                         'L-Aspartate': 'L-Aspartate',
                         'L-Cysteine': 'L-Cysteine',
                         'Glycerol 3-phosphate': 'Glycerol<br>3-phosphate',
                         '3-Hydroxypropanoate': '3-Hydroxy<br>propanoate',
                         '(S)-Propane-1,2-diol': '(S)-Propanediol',
                         '(R)-Propane-1,2-diol': '(R)-Propanediol',
                         'D-Alanine': 'D-Alanine',
                         'Glycerol': 'Glycerol',
                         '(R)-Glycerate': '(R)-Glycerate',
                         'D-Glyceraldehyde': 'Glyceraldehyde',
                         'L-Lactate': 'L-Lactate',
                         'Dihydroxyacetone': 'Dihydroxy-<br>acetone',
                         'L-Alanine': 'L-Alanine',
                         'D-Lactate': 'D-Lactate',
                         'L-Serine': 'L-Serine',
                         'Pyruvate': 'Pyruvate',
                         'Ethanolamine': 'Ethanolamine',
                         'Ethanol': 'Ethanol',
                         'Acetaldehyde': 'Acetaldehyde',
                         'Glycine': 'Glycine',
                         'Acetate': 'Acetate',
                         'Glycolate C2H3O3': 'Glycolate',
                         'Urea CH4N2O': 'Urea',
                         'Formate': 'Formate',
                         'Reduced glutathione': 'Glutathione',
                         '5-Methylthio-D-ribose': '5-Methylthio-<br>ribose',
                         '1,5-Diaminopentane': 'Cadaverine'}

metabolite_lookup_dict = {metabolite_names_dict[key]:key for key in metabolite_names_dict}

carbon_dict = {metabolite.name:str(metabolite.elements['C'])
               if 'C' in metabolite.elements else '0'
               for metabolite in model.metabolites}

carbon_dict = {metabolite:carbon_dict[metabolite] 
               if int(carbon_dict[metabolite])<=6 else '>6'
               for metabolite in metabolite_names_dict}
data = {'names':[metabolite_names_dict[product] for product in carbon_dict.keys()], 'number':list(carbon_dict.values())}
metabolite_df = pd.DataFrame(data,index=list(carbon_dict.keys()))
metabolite_order = metabolite_df.sort_values(by=['number','names']).names.values

# %%
import sys
import colorlover as cl
from plotly import tools, subplots
import plotly.graph_objs as go
import pickle
import plotly.io as pio
pio.templates.default = "none"
import os

try:
    _ = __IPYTHON__
except NameError:
    from plotly.offline import plot
else:
    if 'ipykernel' in sys.modules:
        from plotly.offline import init_notebook_mode
        from plotly.offline import iplot as plot
        from IPython.display import HTML
        HTML("""
             <script>
              var waitForPlotly = setInterval( function() {
              if( typeof(window.Plotly) !== "undefined" ){
              MathJax.Hub.Config({ SVG: { font: "STIX-Web" }, displayAlign: "center" });
              MathJax.Hub.Queue(["setRenderer", MathJax.Hub, "SVG"]);
              clearInterval(waitForPlotly);}}, 250 );
            </script>
            """
        )
        init_notebook_mode(connected=True)
    elif 'IPython' in sys.modules:
        from plotly.offline import plot
    else:
        warn('Unknown ipython configuration')
        from plotly.offline import plot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def prod_constraint_yield_calculator(pecaso_template, constraint):
    temp = deepcopy(pecaso_template)
    pecaso_dict = {}
    temp.settings.productivity_constraint = constraint
    temp.calculate_fermentation_characteristics()
    
    pecaso_dict['constraint'] = constraint
    
    if temp.two_stage_best_batch:
        pecaso_dict['ts_best'] = {}
        pecaso_dict['ts_best']['batch_productivity'] = temp.two_stage_best_batch.batch_productivity
        pecaso_dict['ts_best']['batch_yield'] = temp.two_stage_best_batch.batch_yield
        pecaso_dict['ts_best']['batch_titer'] = temp.two_stage_best_batch.batch_titer
        pecaso_dict['ts_best']['optimal_switch_time'] = temp.two_stage_best_batch.optimal_switch_time
        pecaso_dict['ts_best']['stage_one_factor'] = temp.two_stage_best_batch.stage_one_factor
        pecaso_dict['ts_best']['stage_two_factor'] = temp.two_stage_best_batch.stage_two_factor
        pecaso_dict['ts_best']['objective_value'] = temp.two_stage_best_batch.objective_value
    else:
        pecaso_dict['ts_best'] = None

    if temp.one_stage_best_batch:
        pecaso_dict['os_best'] = {}
        pecaso_dict['os_best']['batch_productivity'] = temp.one_stage_best_batch.batch_productivity
        pecaso_dict['os_best']['batch_yield'] = temp.one_stage_best_batch.batch_yield
        pecaso_dict['os_best']['batch_titer'] = temp.one_stage_best_batch.batch_titer
        pecaso_dict['os_best']['optimal_switch_time'] = temp.one_stage_best_batch.optimal_switch_time
        pecaso_dict['os_best']['stage_one_factor'] = temp.one_stage_best_batch.stage_one_factor
        pecaso_dict['os_best']['stage_two_factor'] = temp.one_stage_best_batch.stage_two_factor
        pecaso_dict['os_best']['objective_value'] = temp.one_stage_best_batch.objective_value
    else:
        pecaso_dict['os_best'] = None
    
    if temp.two_stage_suboptimal_batch:
        pecaso_dict['ts_sub'] = {}
        pecaso_dict['ts_sub']['batch_productivity'] = temp.two_stage_suboptimal_batch.batch_productivity
        pecaso_dict['ts_sub']['batch_yield'] = temp.two_stage_suboptimal_batch.batch_yield
        pecaso_dict['ts_sub']['batch_titer'] = temp.two_stage_suboptimal_batch.batch_titer
        pecaso_dict['ts_sub']['optimal_switch_time'] = temp.two_stage_suboptimal_batch.optimal_switch_time
        pecaso_dict['ts_sub']['stage_one_factor'] = temp.two_stage_suboptimal_batch.stage_one_factor
        pecaso_dict['ts_sub']['stage_two_factor'] = temp.two_stage_suboptimal_batch.stage_two_factor
        pecaso_dict['ts_sub']['objective_value'] = temp.two_stage_suboptimal_batch.objective_value
    else:
        pecaso_dict['ts_sub'] = None

    return pecaso_dict

# %% [markdown]
# # Substrate Uptake: Logistic #
# # Objective: Yield #
# ### Constrained Metric: Productivity ##

# %% [raw]
# pickling_off = open("productivity_constrained_production_log.pickle","rb")
# prod_constrained_production_log = pickle.load(pickling_off)
# pickling_off.close()
#
# start = time.time()
#
# mcpecaso.settings.uptake_fun = 'logistic'
# mcpecaso.settings.uptake_params = {'B': 5}
# mcpecaso.settings.objective = 'batch_yield'
# #pecaso_dict = {}
# #prod_constrained_production_log = {}
# for i, product in enumerate(metabolite_names_dict.keys()):
#     print("Evaluating Product ", i+1, ": ", product)
#     prod_constrained_production_log[product] = {}
#     target_rxn = [reaction for reaction in model.exchanges
#                   if reaction.reactants[0].name==product][0]
#     pecaso_template = mcPECASO(model=model,biomass_rxn=model.reactions.BIOMASS_Ec_iJO1366_core_53p95M,
#                             substrate_rxn=model.reactions.EX_glc__D_e, target_rxn=target_rxn,
#                             condition='Logistic Uptake')
#     temp = deepcopy(pecaso_template)
#     temp.settings.objective = 'batch_productivity'
#     temp.calculate_fermentation_characteristics()
#     max_productivity = temp.two_stage_best_batch.batch_productivity
#     productivity_constraints = np.linspace(0,(int(max_productivity/10)+1)*10,(int(max_productivity/10)+1)*10+1)
#     results_list = Parallel(n_jobs=num_cores, verbose=5)(
#                     delayed(prod_constraint_yield_calculator)(pecaso_template, constraint)
#                     for constraint in productivity_constraints)
#
# for item in results_list:
#     prod_constrained_production_log[product][item['constraint']] = {}
#     prod_constrained_production_log[product][item['constraint']]['ts_best'] = item['ts_best']
#     prod_constrained_production_log[product][item['constraint']]['ts_sub'] = item['ts_sub']
#     prod_constrained_production_log[product][item['constraint']]['os_best'] = item['os_best']
#
# pickling_on = open("productivity_constrained_production_log.pickle","wb")
# #pickle.dump(prod_constrained_production_log, pickling_on)
# pickling_on.close()
# del(pecaso_template)
# end = time.time()
# print(end-start)

# %%
pickling_off = open("productivity_constrained_production_log.pickle","rb")
pecaso_dict = pickle.load(pickling_off)
pickling_off.close()

# %%
results_dict = {}
for product in pecaso_dict.keys():
    results_dict[product] = {}
    ts_best_productivities = [pecaso_dict[product][constraint]['ts_best']['batch_productivity']
                              if pecaso_dict[product][constraint]['ts_best'] else np.nan for constraint in pecaso_dict[product].keys()]
    if np.nan in ts_best_productivities:
        ts_best_productivities[ts_best_productivities.index(np.nan)] = 0


    ts_best_yields = [pecaso_dict[product][constraint]['ts_best']['batch_yield']
                      if pecaso_dict[product][constraint]['ts_best'] else np.nan for constraint in pecaso_dict[product].keys()]
    if np.nan in ts_best_yields:
        ts_best_yields[ts_best_yields.index(np.nan)] = 0
    constraints_productivity = list(pecaso_dict[product].keys())
    if ts_best_yields[-1]!=0:
        ts_best_productivities.append(2*ts_best_productivities[-1] - ts_best_productivities[-2])
        ts_best_yields.append(0)
        constraints_productivity.append(2*constraints_productivity[-1] - constraints_productivity[-2])





    os_best_productivities = [pecaso_dict[product][constraint]['os_best']['batch_productivity']
                              if pecaso_dict[product][constraint]['os_best'] else np.nan for constraint in pecaso_dict[product].keys()]
    os_best_productivities[os_best_productivities.index(np.nan)] = 0
    os_best_yields = [pecaso_dict[product][constraint]['os_best']['batch_yield'] 
                      if pecaso_dict[product][constraint]['os_best'] else np.nan for constraint in pecaso_dict[product].keys()]
    os_best_yields[os_best_yields.index(np.nan)] = 0



    ts_sub_productivities = [pecaso_dict[product][constraint]['ts_sub']['batch_productivity']
                             if pecaso_dict[product][constraint]['ts_sub']
                             else np.nan for constraint in pecaso_dict[product].keys()]
    ts_sub_productivities[ts_sub_productivities.index(np.nan)] = 0
    ts_sub_yields = [pecaso_dict[product][constraint]['ts_sub']['batch_yield']
                     if pecaso_dict[product][constraint]['ts_sub']
                     else np.nan for constraint in pecaso_dict[product].keys()]
    ts_sub_yields[ts_sub_yields.index(np.nan)] = 0



    max_yield = max(os_best_yields)
    molar_mass = [metabolite for metabolite in model.metabolites if metabolite.name==product][0].formula_weight

    results_dict[product]['ts_best_productivities'] = np.array(ts_best_productivities)*molar_mass/1000
    results_dict[product]['ts_best_yields'] = np.array(ts_best_yields)/max_yield*100
    results_dict[product]['os_best_productivities'] = np.array(os_best_productivities)*molar_mass/1000
    results_dict[product]['os_best_yields'] = np.array(os_best_yields)/max_yield*100
    results_dict[product]['ts_sub_productivities'] = np.array(ts_sub_productivities)*molar_mass/1000
    results_dict[product]['ts_sub_yields'] = np.array(ts_sub_yields)/max_yield*100
    results_dict[product]['constraints_productivity'] = np.array(constraints_productivity)*molar_mass/1000

# %%
for k,carbon_number in enumerate(sorted(set(metabolite_df.number.values))):
    print("No. of carbons: ", carbon_number)
    metabolite_list = metabolite_df[metabolite_df.number==carbon_number].sort_values(by='names').index
    num_rows = int(len(metabolite_list)/6-0.1)+1
    titles = [metabolite_names_dict[metabolite] for metabolite in metabolite_list]
    fig = subplots.make_subplots(rows=num_rows, cols=6, subplot_titles=titles,print_grid=False, horizontal_spacing=0.042)
    for i,product in enumerate(metabolite_list):

        fig.add_trace(go.Scatter(x=results_dict[product]['constraints_productivity'][1::], 
                                    y=results_dict[product]['ts_best_yields'][1::],
                                    name='Optimized Two Stage',
                                    legendgroup='ts_best', line={'color': '#8DC447'},
                                    showlegend=False), row=int(i/6)+1, col=int(i%6)+1)

        fig.add_trace(go.Scatter(x=results_dict[product]['constraints_productivity'][1::], 
                                    y=results_dict[product]['ts_sub_yields'][1::],
                                    name='Traditional Two Stage',
                                    legendgroup='ts_sub', line={'color': '#FF5555'},
                                    showlegend=False), row=int(i/6)+1, col=int(i%6)+1)

        fig.add_trace(go.Scatter(x=results_dict[product]['constraints_productivity'][1::], 
                                    y=results_dict[product]['os_best_yields'][1::],
                                    name='Best One Stage',
                                    legendgroup='os_best', line={'color': '#76D1F4'},
                                    showlegend=False), row=int(i/6)+1, col=int(i%6)+1)



        fig.update_xaxes(range=[results_dict[product]['constraints_productivity'][1],
                                int((max(results_dict[product]['ts_best_productivities'])+0.3)*2)/2+0.5],
                         row=int(i/6)+1, col=int(i%6)+1)

        if i%6==0:
            fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, zeroline=False,
                             title_text='Max Yield (% Max)',
                             title_font=dict(size=12, color='black'),
                             title_standoff=0,
                             automargin=True, row=int(i/6)+1, col=int(i%6)+1)

    fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, zeroline=False,
                     title_text='Min Rate (g/L.h)',
                     title_font=dict(size=12, color='black'),
                     tickfont=dict(size=14, color='black'),
                     title_standoff=0,
                     automargin=True,
                     ticks='outside',
                     nticks=5)
    fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, zeroline=False,
                     tickangle=0,
                     ticks='outside',
                     range=[0,100],
                     tickfont=dict(size=14, color='black'))
    fig.update_layout(width=1000,
                      height=90+210*num_rows,
                      margin={'l':8})
    fig.update_annotations(dict(font=dict(size=16, color='black')))

    plot(fig)
    if not os.path.exists('images'):
        os.mkdir('images')
    #pio.write_image(fig, 'images/productivity_constrained_yield_objective_C_'+str(k+1)+'.svg')
# Out:
# No. of carbons:  1
# <div>
#
#
#             <div id="d859d761-60cc-4bbc-b72b-6aa235530150" class="plotly-graph-div" style="height:300px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d859d761-60cc-4bbc-b72b-6aa235530150")) {
#                     Plotly.newPlot(
#                         'd859d761-60cc-4bbc-b72b-6aa235530150',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.39015114666666667, 0.7803022933333333, 1.17045344, 1.5606045866666667, 1.9507557333333332, 2.34090688, 2.7310580266666666, 3.1212091733333334, 3.51136032, 3.9015114666666664, 4.291662613333333, 4.68181376, 5.0719649066666666, 5.462116053333333, 5.8522672, 6.242418346666667, 6.632569493333333, 7.02272064, 7.412871786666667, 7.803022933333333, 8.19317408, 8.583325226666666, 8.973476373333334, 9.36362752, 9.753778666666667, 10.143929813333333, 10.534080959999999, 10.924232106666667, 11.314383253333334, 11.7045344, 12.094685546666668], "xaxis": "x", "y": [91.97200539552394, 91.56474765761592, 91.34859392768828, 91.20089763528806, 89.38909030028309, 87.31097737208323, 85.307736449118, 83.43471862685921, 82.18985730190026, 81.25230453673454, 80.44933331302299, 79.754543132937, 79.07463273744536, 78.41072310756768, 77.76646272284601, 77.195343906555, 76.60364298508281, 75.99749418272506, 75.36136360563187, 74.68698982023896, 73.9699746198901, 73.2041600560484, 72.3649412298854, 71.42915326664348, 70.3334440351325, 68.57027333184, 66.90708639441618, 65.05144663223246, 63.373476462898225, 57.36373502351674, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.39015114666666667, 0.7803022933333333, 1.17045344, 1.5606045866666667, 1.9507557333333332, 2.34090688, 2.7310580266666666, 3.1212091733333334, 3.51136032, 3.9015114666666664, 4.291662613333333, 4.68181376, 5.0719649066666666, 5.462116053333333, 5.8522672, 6.242418346666667, 6.632569493333333, 7.02272064, 7.412871786666667, 7.803022933333333, 8.19317408, 8.583325226666666, 8.973476373333334, 9.36362752, 9.753778666666667, 10.143929813333333, 10.534080959999999, 10.924232106666667, 11.314383253333334, 11.7045344, 12.094685546666668], "xaxis": "x", "y": [83.63091896449114, 83.24723230714885, 83.247208308283, 82.45581450731301, 77.14204207170914, 71.28365032237986, 64.12270781411348, 56.94446889631837, 49.0849423586193, 38.43287362790851, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.39015114666666667, 0.7803022933333333, 1.17045344, 1.5606045866666667, 1.9507557333333332, 2.34090688, 2.7310580266666666, 3.1212091733333334, 3.51136032, 3.9015114666666664, 4.291662613333333, 4.68181376, 5.0719649066666666, 5.462116053333333, 5.8522672, 6.242418346666667, 6.632569493333333, 7.02272064, 7.412871786666667, 7.803022933333333, 8.19317408, 8.583325226666666, 8.973476373333334, 9.36362752, 9.753778666666667, 10.143929813333333, 10.534080959999999, 10.924232106666667, 11.314383253333334, 11.7045344, 12.094685546666668], "xaxis": "x", "y": [85.54171835294412, 84.71266468420657, 84.29638350336687, 83.83771565021037, 82.61598977382883, 81.60966957326363, 80.7077212991597, 79.84430489162479, 78.97709894447176, 78.0752669064434, 77.1097969859691, 76.06102047218106, 74.89536173400697, 73.58531096069403, 72.0750685161817, 70.30404565670281, 68.15031879223832, 65.3601819477569, 61.094074788774655, 55.742799248660326, 0.0, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.18016578, 0.36033156, 0.54049734, 0.72066312, 0.9008288999999999, 1.08099468, 1.26116046, 1.44132624, 1.6214920199999998, 1.8016577999999999, 1.98182358, 2.16198936, 2.34215514, 2.52232092, 2.7024867, 2.88265248, 3.06281826, 3.2429840399999996, 3.4231498199999995, 3.6033155999999997, 3.7834813799999996, 3.96364716, 4.14381294, 4.32397872, 4.5041445, 4.68431028, 4.86447606, 5.04464184, 5.22480762, 5.404973 ...
#                         {"annotations": [{"font": {"color": "black", "size": 16}, "showarrow": false, "text": "Formate", "x": 0.06583333333333334, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"color": "black", "size": 16}, "showarrow": false, "text": "Urea", "x": 0.23950000000000002, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "height": 300, "margin": {"l": 8}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "width": 1000, "xaxis": {"anchor": "y", "automargin": true, "domain": [0.0, 0.13166666666666668], "linecolor": "black", "linewidth": 1, "mirror": true, "nticks": 5, "range": [0.39015114666666667, 12.0], "showline": true, "tickfont": {"color": "black", "size": 14}, "ticks": "outside", "title": {"font": {"color": "black", "size": 12}, "standoff": 0, "text": "Min Rate (g/L.h)"}, "zeroline": false}, "xaxis2": {"anchor": "y2", "automargin":
# No. of carbons:  2
# <div>
#
#
#             <div id="a277cb7a-6a7b-4896-a4f9-91dd5b2efba0" class="plotly-graph-div" style="height:300px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a277cb7a-6a7b-4896-a4f9-91dd5b2efba0")) {
#                     Plotly.newPlot(
#                         'a277cb7a-6a7b-4896-a4f9-91dd5b2efba0',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.10278930666666668, 0.20557861333333335, 0.30836792, 0.4111572266666667, 0.5139465333333334, 0.61673584, 0.7195251466666668, 0.8223144533333334, 0.9251037599999999, 1.0278930666666668, 1.1306823733333333, 1.23347168, 1.3362609866666666, 1.4390502933333336, 1.5418396, 1.6446289066666668, 1.7474182133333336, 1.8502075199999999, 1.9529968266666666, 2.0557861333333336, 2.15857544, 2.2613647466666666, 2.364154053333334, 2.46694336, 2.569732666666667, 2.672521973333333, 2.7753112800000004, 2.878100586666667, 2.9808898933333334, 3.0836792, 3.1864685066666665], "xaxis": "x", "y": [90.71530821582805, 90.31983882160132, 90.11043066751448, 89.19498612326979, 85.77648715012069, 84.18050187051378, 82.36209137635784, 80.71487414088945, 79.46562331311993, 78.46548014513893, 77.59714347747672, 76.78961449560485, 76.02109979608831, 75.31204558767317, 74.64255331268822, 73.90313810329653, 73.2322701107003, 72.45897530288859, 71.63737801828009, 70.73843253495856, 69.71910759313286, 68.56027757220897, 67.27170331503271, 65.28249420069557, 63.28337638601382, 58.716730394783625, 57.59025870728771, 0.0, null, null, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.10278930666666668, 0.20557861333333335, 0.30836792, 0.4111572266666667, 0.5139465333333334, 0.61673584, 0.7195251466666668, 0.8223144533333334, 0.9251037599999999, 1.0278930666666668, 1.1306823733333333, 1.23347168, 1.3362609866666666, 1.4390502933333336, 1.5418396, 1.6446289066666668, 1.7474182133333336, 1.8502075199999999, 1.9529968266666666, 2.0557861333333336, 2.15857544, 2.2613647466666666, 2.364154053333334, 2.46694336, 2.569732666666667, 2.672521973333333, 2.7753112800000004, 2.878100586666667, 2.9808898933333334, 3.0836792, 3.1864685066666665], "xaxis": "x", "y": [82.99345556205108, 82.74910281320653, 82.65909436394651, 79.03635587793798, 73.13803702181968, 68.04237982672477, 58.61868222843842, 48.75224762927911, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.10278930666666668, 0.20557861333333335, 0.30836792, 0.4111572266666667, 0.5139465333333334, 0.61673584, 0.7195251466666668, 0.8223144533333334, 0.9251037599999999, 1.0278930666666668, 1.1306823733333333, 1.23347168, 1.3362609866666666, 1.4390502933333336, 1.5418396, 1.6446289066666668, 1.7474182133333336, 1.8502075199999999, 1.9529968266666666, 2.0557861333333336, 2.15857544, 2.2613647466666666, 2.364154053333334, 2.46694336, 2.569732666666667, 2.672521973333333, 2.7753112800000004, 2.878100586666667, 2.9808898933333334, 3.0836792, 3.1864685066666665], "xaxis": "x", "y": [83.92420244495085, 83.02161328822196, 82.56900997064382, 81.40025748330224, 80.06389978469996, 78.95261080371967, 77.93893491007168, 76.9487467767629, 75.9335767495712, 74.85073015212784, 73.67403849568085, 72.34215757880608, 70.82843568642417, 69.04332994658257, 66.87157925444706, 63.67497320261971, 58.14303629048746, 0.0, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.15745072, 0.31490144, 0.47235216, 0.62980288, 0.7872536, 0.94470432, 1.10215504, 1.25960576, 1.4170564800000003, 1.5745072, 1.7319579200000002, 1.88940864, 2.04685936, 2.20431008, 2.3617608, 2.51921152, 2.6766622399999997, 2.8341129600000006, 2.99156368, 3.1490144, 3.3064651200000004, 3.4639158400000003, 3.62136656, 3.77881728, 3.9362679999999997, 4.09371872, 4.251169440000001, 4.40862016, 4.56607088, 4.7235216], "xaxis": "x2", "y ...
# No. of carbons:  3
# <div>
#
#
#             <div id="c9ad9569-398a-4ab5-bbab-f61f4afb5229" class="plotly-graph-div" style="height:720px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c9ad9569-398a-4ab5-bbab-f61f4afb5229")) {
#                     Plotly.newPlot(
#                         'c9ad9569-398a-4ab5-bbab-f61f4afb5229',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.17511566666666667, 0.35023133333333334, 0.525347, 0.7004626666666667, 0.8755783333333333, 1.050694, 1.2258096666666667, 1.4009253333333334, 1.576041, 1.7511566666666667, 1.9262723333333336, 2.101388, 2.276503666666667, 2.4516193333333334, 2.626735, 2.8018506666666667, 2.976966333333334, 3.152082, 3.3271976666666667, 3.5023133333333334, 3.677429, 3.852544666666667, 4.027660333333333, 4.202776, 4.377891666666668, 4.553007333333334, 4.728123, 4.903238666666667, 5.078354333333333, 5.25347, 5.428585666666667], "xaxis": "x", "y": [90.9196592176388, 90.53560566209295, 90.33334576197171, 88.87584553319539, 86.18099895735347, 83.61670826739756, 81.1114721660728, 79.31981523803626, 78.18137560148529, 77.25115932842341, 76.40683198116675, 75.61810608808888, 74.85266607845402, 74.12754986216548, 73.35989587937831, 72.55266001863029, 71.81282523765704, 70.96970453512675, 70.04647376058188, 69.00786336461154, 67.56356051602208, 66.45758138414273, 64.06634640660039, 61.98841913764315, 58.47275078808409, 0.0, null, null, null, null, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.17511566666666667, 0.35023133333333334, 0.525347, 0.7004626666666667, 0.8755783333333333, 1.050694, 1.2258096666666667, 1.4009253333333334, 1.576041, 1.7511566666666667, 1.9262723333333336, 2.101388, 2.276503666666667, 2.4516193333333334, 2.626735, 2.8018506666666667, 2.976966333333334, 3.152082, 3.3271976666666667, 3.5023133333333334, 3.677429, 3.852544666666667, 4.027660333333333, 4.202776, 4.377891666666668, 4.553007333333334, 4.728123, 4.903238666666667, 5.078354333333333, 5.25347, 5.428585666666667], "xaxis": "x", "y": [83.66764345999992, 83.44355924165386, 83.31352509587857, 78.570315561139, 72.22990856386518, 64.277267672, 55.69300720162709, 37.67422548156305, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.17511566666666667, 0.35023133333333334, 0.525347, 0.7004626666666667, 0.8755783333333333, 1.050694, 1.2258096666666667, 1.4009253333333334, 1.576041, 1.7511566666666667, 1.9262723333333336, 2.101388, 2.276503666666667, 2.4516193333333334, 2.626735, 2.8018506666666667, 2.976966333333334, 3.152082, 3.3271976666666667, 3.5023133333333334, 3.677429, 3.852544666666667, 4.027660333333333, 4.202776, 4.377891666666668, 4.553007333333334, 4.728123, 4.903238666666667, 5.078354333333333, 5.25347, 5.428585666666667], "xaxis": "x", "y": [83.02230710147352, 82.13198730482328, 81.68416864854203, 80.20208017731316, 78.87977339898028, 77.76774686275773, 76.74033465137782, 75.7236186985247, 74.66659837228124, 73.53115450426708, 72.2695986126085, 70.84076461806147, 69.17653927760506, 67.1789820716812, 64.66747036453872, 61.10459878247539, 54.09144088186586, 0.0, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.10145922666666667, 0.20291845333333333, 0.30437768, 0.40583690666666666, 0.5072961333333332, 0.60875536, 0.7102145866666666, 0.8116738133333333, 0.91313304, 1.0145922666666665, 1.1160514933333334, 1.21751072, 1.3189699466666667, 1.4204291733333332, 1.5218884000000001, 1.6233476266666667, 1.724806853333333, 1.82626608, 1.9277253066666664, 2.029184533333333, 2.13064376, 2.232102986666667, 2.3335622133333334, 2.43502144, 2.5364806666666664, 2.6379398933333333, 2.73939912, 2.8408583466666664, 2.9423175733333333, 3.0437768000000003, 3.145236026666667], "xaxis": "x2", "y": [91.34665141683294, 90.95101573892995, 9 ...
# No. of carbons:  4
# <div>
#
#
#             <div id="d234b12a-0b88-4932-8c1e-d8bf3ae0b5a6" class="plotly-graph-div" style="height:510px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d234b12a-0b88-4932-8c1e-d8bf3ae0b5a6")) {
#                     Plotly.newPlot(
#                         'd234b12a-0b88-4932-8c1e-d8bf3ae0b5a6',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.21082058666666664, 0.4216411733333333, 0.63246176, 0.8432823466666666, 1.0541029333333334, 1.26492352, 1.4757441066666666, 1.6865646933333331, 1.89738528, 2.1082058666666668, 2.3190264533333336, 2.52984704, 2.7406676266666667, 2.951488213333333, 3.1623088000000004, 3.3731293866666663, 3.583949973333333, 3.79477056, 4.005591146666666, 4.2164117333333335, 4.42723232, 4.638052906666667, 4.8488734933333335, 5.05969408, 5.270514666666666, 5.4813352533333335, 5.692155840000001, 5.902976426666666, 6.113797013333333, 6.324617600000001], "xaxis": "x", "y": [91.07447602942781, 90.66678381686586, 90.45066822624153, 89.63767373331262, 88.15517171219798, 85.99048836456747, 83.80192895200933, 82.22434678489071, 80.91995268333721, 79.9355628562089, 79.12917067288704, 78.38548717618902, 77.67908263426958, 76.98386353754148, 76.28719615126317, 75.6504320241753, 75.09558402510872, 74.19955172982638, 73.96969176389042, 73.15766455361221, 70.55965131559189, 69.55342959454713, 68.49623807481534, 69.61766379526965, 66.58577132306779, 64.84028095379627, 63.16797828154006, 61.55698743680843, 58.18079013521977, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.21082058666666664, 0.4216411733333333, 0.63246176, 0.8432823466666666, 1.0541029333333334, 1.26492352, 1.4757441066666666, 1.6865646933333331, 1.89738528, 2.1082058666666668, 2.3190264533333336, 2.52984704, 2.7406676266666667, 2.951488213333333, 3.1623088000000004, 3.3731293866666663, 3.583949973333333, 3.79477056, 4.005591146666666, 4.2164117333333335, 4.42723232, 4.638052906666667, 4.8488734933333335, 5.05969408, 5.270514666666666, 5.4813352533333335, 5.692155840000001, 5.902976426666666, 6.113797013333333, 6.324617600000001], "xaxis": "x", "y": [82.83574694008169, 82.77902400674188, 82.6716967752563, 80.96170832970525, 75.89820141815483, 71.16560992396003, 63.69255186652643, 53.44750742292784, 43.45256401421116, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.21082058666666664, 0.4216411733333333, 0.63246176, 0.8432823466666666, 1.0541029333333334, 1.26492352, 1.4757441066666666, 1.6865646933333331, 1.89738528, 2.1082058666666668, 2.3190264533333336, 2.52984704, 2.7406676266666667, 2.951488213333333, 3.1623088000000004, 3.3731293866666663, 3.583949973333333, 3.79477056, 4.005591146666666, 4.2164117333333335, 4.42723232, 4.638052906666667, 4.8488734933333335, 5.05969408, 5.270514666666666, 5.4813352533333335, 5.692155840000001, 5.902976426666666, 6.113797013333333, 6.324617600000001], "xaxis": "x", "y": [84.57347462160861, 83.71016048817343, 83.27763253975053, 82.64577631161309, 81.37230595888808, 80.32345154766597, 79.38103442297079, 78.47693450188525, 77.56563339292771, 76.61477857230112, 75.59128786288835, 74.46954205902958, 73.21788221138134, 71.7924905806541, 70.1292689700245, 68.14709413991947, 65.63947304081107, 61.963560073929926, 54.234453242729806, 0.0, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.22019653333333336, 0.4403930666666667, 0.6605896, 0.8807861333333334, 1.1009826666666667, 1.3211792, 1.5413757333333336, 1.7615722666666669, 1.9817688, 2.2019653333333333, 2.422161866666667, 2.6423584, 2.8625549333333336, 3.082751466666667, 3.3029479999999998, 3.5231445333333338, 3.743341066666667, 3.9635376, 4.183734133333333, 4.403930666666667, 4.6241272, 4.844323733333334, 5.064520266666667, 5.2847168, 5.5049133333333335, 5.725109866666667, ...
# No. of carbons:  5
# <div>
#
#
#             <div id="55e138f3-43b2-445c-a8a8-aabed89a4c35" class="plotly-graph-div" style="height:720px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("55e138f3-43b2-445c-a8a8-aabed89a4c35")) {
#                     Plotly.newPlot(
#                         '55e138f3-43b2-445c-a8a8-aabed89a4c35',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.1351267, 0.2702534, 0.40538009999999997, 0.5405068, 0.6756335, 0.8107601999999999, 0.9458869, 1.0810136, 1.2161403, 1.351267, 1.4863937, 1.6215203999999999, 1.7566471, 1.8917738, 2.0269005, 2.1620272, 2.2971538999999996, 2.4322806, 2.5674072999999997, 2.702534, 2.8376607, 2.9727874, 3.1079141, 3.2430407999999997, 3.3781675, 3.5132942, 3.6484209, 3.7835476, 3.9186743, 4.053801, 4.1889277], "xaxis": "x", "y": [91.28021428140248, 90.88059918664847, 90.66640486192084, 89.90386705412638, 87.55568827889181, 85.2933468232868, 83.07899258836959, 81.73646477575187, 80.66095170787703, 79.83276282902582, 79.04977836499421, 78.29728266547606, 77.54686356843524, 76.90656003882924, 76.25549445963668, 75.57639794314525, 74.85353669565913, 74.09321499973693, 73.27384792951564, 72.37970995487343, 71.39483732039606, 70.24263976942113, 67.56789087291651, 67.48824639894119, 64.59226731765952, 61.862838270589215, 57.38763235887819, 0.0, null, null, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.1351267, 0.2702534, 0.40538009999999997, 0.5405068, 0.6756335, 0.8107601999999999, 0.9458869, 1.0810136, 1.2161403, 1.351267, 1.4863937, 1.6215203999999999, 1.7566471, 1.8917738, 2.0269005, 2.1620272, 2.2971538999999996, 2.4322806, 2.5674072999999997, 2.702534, 2.8376607, 2.9727874, 3.1079141, 3.2430407999999997, 3.3781675, 3.5132942, 3.6484209, 3.7835476, 3.9186743, 4.053801, 4.1889277], "xaxis": "x", "y": [82.80197723841121, 82.76120824883122, 82.65453665911882, 79.20959263874869, 73.35302997269446, 67.9094328712287, 58.21930211582882, 48.78474421671584, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.1351267, 0.2702534, 0.40538009999999997, 0.5405068, 0.6756335, 0.8107601999999999, 0.9458869, 1.0810136, 1.2161403, 1.351267, 1.4863937, 1.6215203999999999, 1.7566471, 1.8917738, 2.0269005, 2.1620272, 2.2971538999999996, 2.4322806, 2.5674072999999997, 2.702534, 2.8376607, 2.9727874, 3.1079141, 3.2430407999999997, 3.3781675, 3.5132942, 3.6484209, 3.7835476, 3.9186743, 4.053801, 4.1889277], "xaxis": "x", "y": [84.8859639503196, 84.0917210876593, 83.69075642942173, 82.74328113833963, 81.5308749284957, 80.49226373974172, 79.5193853662385, 78.54575717242899, 77.52804307573999, 76.42629908881737, 75.20539261793611, 73.82443931744868, 72.22441573219096, 70.31988979820551, 67.97093845976873, 64.83484209846378, 59.67628997035448, 54.62540989673449, 0.0, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.13220734, 0.26441468, 0.39662202, 0.52882936, 0.6610367000000001, 0.79324404, 0.92545138, 1.05765872, 1.1898660600000002, 1.3220734000000003, 1.4542807400000002, 1.58648808, 1.7186954200000002, 1.85090276, 1.9831101000000004, 2.11531744, 2.24752478, 2.3797321200000003, 2.5119394600000007, 2.6441468000000006, 2.7763541400000005, 2.9085614800000004, 3.0407688200000003, 3.17297616, 3.3051835000000005, 3.4373908400000004, 3.5695981800000003, 3.70180552, 3.83401286, 3.966220200000001, 4.09842754], "xaxis": "x2", "y": [91.18155838186648, 90.79730950969272, 88.58604801721576, 87.64434874683772, 84.8570187784395, 82.4682033872425, 81.04087430854369, 79.93008906140169, 78.98028014123224, 78.0556839162768, 77.20415885517953, 76.39493749068626, 75.54804717937948, 74.64079533515496, 73.66668411090207, 72.57143484312878, 71.32033416568588, 68.97729173136983, 66.42581398012997, 64.71056230236452, 61.34115442299778, 57.6049980 ...
# No. of carbons:  6
# <div>
#
#
#             <div id="2378de0c-7860-438c-aa7f-e7fb9ab823af" class="plotly-graph-div" style="height:510px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2378de0c-7860-438c-aa7f-e7fb9ab823af")) {
#                     Plotly.newPlot(
#                         '2378de0c-7860-438c-aa7f-e7fb9ab823af',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.19313146, 0.38626292, 0.57939438, 0.77252584, 0.9656573, 1.15878876, 1.35192022, 1.54505168, 1.73818314, 1.9313146, 2.1244460600000004, 2.31757752, 2.51070898, 2.70384044, 2.8969719, 3.09010336, 3.28323482, 3.47636628, 3.66949774, 3.8626292, 4.05576066, 4.248892120000001, 4.44202358, 4.63515504, 4.8282865, 5.02141796, 5.21454942, 5.40768088, 5.60081234, 5.7939438, 5.98707526], "xaxis": "x", "y": [91.77420144501292, 91.38538982535862, 91.17634576656201, 90.53311617227762, 88.34316880256321, 86.22396339429028, 84.22267295081302, 82.90527193297763, 81.88628066999337, 81.10542576676724, 80.36030741842396, 79.63244876026255, 78.92651977667019, 78.25065073832846, 77.62378049448984, 76.97500966872607, 76.28587583029355, 75.5668510244608, 74.78615359798931, 73.04817170938126, 73.02680070753506, 72.00325811515881, 70.19937750164647, 67.82570200240117, 67.01143696103095, 65.21292176749056, 60.64465641224089, 59.552155273478476, 0.0, null, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.19313146, 0.38626292, 0.57939438, 0.77252584, 0.9656573, 1.15878876, 1.35192022, 1.54505168, 1.73818314, 1.9313146, 2.1244460600000004, 2.31757752, 2.51070898, 2.70384044, 2.8969719, 3.09010336, 3.28323482, 3.47636628, 3.66949774, 3.8626292, 4.05576066, 4.248892120000001, 4.44202358, 4.63515504, 4.8282865, 5.02141796, 5.21454942, 5.40768088, 5.60081234, 5.7939438, 5.98707526], "xaxis": "x", "y": [82.83422196787839, 82.76252811037007, 82.64598727365248, 79.34003777633608, 73.67713297363014, 67.90925458718664, 59.95199205369305, 49.37401197923981, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.19313146, 0.38626292, 0.57939438, 0.77252584, 0.9656573, 1.15878876, 1.35192022, 1.54505168, 1.73818314, 1.9313146, 2.1244460600000004, 2.31757752, 2.51070898, 2.70384044, 2.8969719, 3.09010336, 3.28323482, 3.47636628, 3.66949774, 3.8626292, 4.05576066, 4.248892120000001, 4.44202358, 4.63515504, 4.8282865, 5.02141796, 5.21454942, 5.40768088, 5.60081234, 5.7939438, 5.98707526], "xaxis": "x", "y": [85.84838555252303, 85.09671001302648, 84.71653065040279, 83.8979478955588, 82.74744529332543, 81.75934555338142, 80.83201541659231, 79.90607216161007, 78.9359819571859, 77.89239187462412, 76.73853579048026, 75.44040980108431, 73.94719080473556, 72.20164005609794, 70.08520733427315, 67.37623173976395, 63.48457670229104, 55.59571032676419, 0.0, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.06007402666666667, 0.12014805333333334, 0.18022208, 0.24029610666666668, 0.30037013333333334, 0.36044416, 0.4205181866666666, 0.48059221333333335, 0.54066624, 0.6007402666666667, 0.6608142933333333, 0.72088832, 0.7809623466666666, 0.8410363733333333, 0.9011104, 0.9611844266666667, 1.0212584533333333, 1.08133248, 1.1414065066666668, 1.2014805333333334, 1.26155456, 1.3216285866666666, 1.3817026133333334, 1.44177664, 1.5018506666666664, 1.5619246933333333, 1.6219987200000001, 1.6820727466666665, 1.7421467733333333, 1.8022208, 1.8622948266666668], "xaxis": "x2", "y": [91.11714357035943, 90.73589750011571, 90.06186118390384, 86.98617691086596, 84.07520163301338, 81.87580597459541, 80.48393867447406, 79.44236285368453, 78.44073340076918, 77.60561926876693, 76.53190052785654, 76.17172763035038, 75.30397441895657, 74.37724553424889, 73.36491715421366, 72.2293443643574, 69.19020933067132, 68.24659664970181, 66.65565254928177, 64.66009358747 ...
# No. of carbons:  >6
# <div>
#
#
#             <div id="aeffa1ae-1e2d-4e38-bf3b-b4537cadc06f" class="plotly-graph-div" style="height:720px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aeffa1ae-1e2d-4e38-bf3b-b4537cadc06f")) {
#                     Plotly.newPlot(
#                         'aeffa1ae-1e2d-4e38-bf3b-b4537cadc06f',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.17816087999999997, 0.35632175999999993, 0.5344826399999999, 0.7126435199999999, 0.8908043999999998, 1.0689652799999998, 1.2471261599999999, 1.4252870399999997, 1.6034479199999998, 1.7816087999999997, 1.9597696799999997, 2.1379305599999996, 2.3160914399999997, 2.4942523199999997, 2.6724132, 2.8505740799999995, 3.0287349599999995, 3.2068958399999996, 3.3850567199999997, 3.5632175999999993, 3.7413784799999994, 3.9195393599999995, 4.097700239999999, 4.275861119999999, 4.454021999999999, 4.632182879999999, 4.810343759999999, 4.9885046399999995, 5.16666552, 5.3448264, 5.52298728], "xaxis": "x", "y": [91.14511778546188, 90.76447925315728, 90.02106548757159, 86.30728131885623, 84.03618326214597, 81.79402904717563, 80.55028530307162, 79.46178045026909, 78.45846923386843, 77.48332250748456, 76.63082101357104, 75.74258643140564, 74.79941322625243, 73.75028540970163, 72.61050606959213, 71.30130828004107, 69.03815213924715, 66.96085788193895, 64.32014869145131, 59.57602903370226, 0.0, null, null, null, null, null, null, null, null, null, 0.0], "yaxis": "y"}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.17816087999999997, 0.35632175999999993, 0.5344826399999999, 0.7126435199999999, 0.8908043999999998, 1.0689652799999998, 1.2471261599999999, 1.4252870399999997, 1.6034479199999998, 1.7816087999999997, 1.9597696799999997, 2.1379305599999996, 2.3160914399999997, 2.4942523199999997, 2.6724132, 2.8505740799999995, 3.0287349599999995, 3.2068958399999996, 3.3850567199999997, 3.5632175999999993, 3.7413784799999994, 3.9195393599999995, 4.097700239999999, 4.275861119999999, 4.454021999999999, 4.632182879999999, 4.810343759999999, 4.9885046399999995, 5.16666552, 5.3448264, 5.52298728], "xaxis": "x", "y": [82.82265587073633, 82.6935965674586, 79.42713975237533, 71.50043735461843, 63.73843781221419, 49.43573427881255, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.17816087999999997, 0.35632175999999993, 0.5344826399999999, 0.7126435199999999, 0.8908043999999998, 1.0689652799999998, 1.2471261599999999, 1.4252870399999997, 1.6034479199999998, 1.7816087999999997, 1.9597696799999997, 2.1379305599999996, 2.3160914399999997, 2.4942523199999997, 2.6724132, 2.8505740799999995, 3.0287349599999995, 3.2068958399999996, 3.3850567199999997, 3.5632175999999993, 3.7413784799999994, 3.9195393599999995, 4.097700239999999, 4.275861119999999, 4.454021999999999, 4.632182879999999, 4.810343759999999, 4.9885046399999995, 5.16666552, 5.3448264, 5.52298728], "xaxis": "x", "y": [84.6338258857941, 83.89728809653073, 82.87741425961893, 81.30607665475674, 79.9801953388864, 78.69808836163763, 77.34215897268214, 75.824284248727, 74.06017701384333, 71.92250572962439, 69.20610989352186, 65.43235705892563, 58.109782943102736, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "yaxis": "y"}, {"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.16214441333333335, 0.3242888266666667, 0.48643324000000004, 0.6485776533333334, 0.8107220666666667, 0.9728664800000001, 1.1350108933333334, 1.2971553066666668, 1.4592997200000002, 1.6214441333333334, 1.7835885466666668, 1.9457329600000002, 2.107877373333334, 2.2700217866666668, 2.4321662000000006, 2.5943106133333336, 2.756455026666667, 2.9185994400000004, 3.080743853333334, 3.2428882666666667, 3.40503268, 3.5671770933333335, 3.729321506666667, 3.8914659200000004, 4.053610333333333, 4.215754746666668, 4.377899160000001, 4.540043573 ...

# %%
fig = go.Figure()
for i,product in enumerate(['D-Lactate']):

    fig.add_trace(go.Scatter(x=results_dict[product]['constraints_productivity'][1::], 
                                y=results_dict[product]['ts_best_yields'][1::],
                                name='Optimized Two Stage',
                                legendgroup='ts_best', line={'color': '#8DC447'},
                                showlegend=False))

    fig.add_trace(go.Scatter(x=results_dict[product]['constraints_productivity'][1::], 
                                y=results_dict[product]['ts_sub_yields'][1::],
                                name='Traditional Two Stage',
                                legendgroup='ts_sub', line={'color': '#FF5555'},
                                showlegend=False))

    fig.add_trace(go.Scatter(x=results_dict[product]['constraints_productivity'][1::], 
                                y=results_dict[product]['os_best_yields'][1::],
                                name='Best One Stage',
                                legendgroup='os_best', line={'color': '#76D1F4'},
                                showlegend=False))

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True, zeroline=False,
                 title_text='Min Yield (% Max)',
                 title_font=dict(size=18, color='black'),
                 tickfont=dict(size=18, color='black'),
                 title_standoff=0,
                 automargin=True,
                 ticks='outside',
                 nticks=10)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True, zeroline=False,
                 ticks='outside',
                 tickfont=dict(size=18, color='black'),
                 range=[0, 100],
                 title_text='Yield (% Max)',
                 title_font=dict(size=18, color='black'),
                 title_standoff=0,
                 automargin=True)
fig.update_layout(width=365,
                  height=400,
                  margin={'l':8})
plot(fig)
if not os.path.exists('images'):
    os.mkdir('images')
#pio.write_image(fig, 'images/productivity_constrained_yield_lactate.svg')
# Out:
# <div>
#
#
#             <div id="ef7755fc-9d66-4270-a2d2-296f0f599bb1" class="plotly-graph-div" style="height:400px; width:365px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef7755fc-9d66-4270-a2d2-296f0f599bb1")) {
#                     Plotly.newPlot(
#                         'ef7755fc-9d66-4270-a2d2-296f0f599bb1',
#                         [{"legendgroup": "ts_best", "line": {"color": "#8DC447"}, "name": "Optimized Two Stage", "showlegend": false, "type": "scatter", "x": [0.17814, 0.35628, 0.53442, 0.71256, 0.8906999999999999, 1.06884, 1.24698, 1.42512, 1.6032599999999997, 1.7813999999999999, 1.95954, 2.13768, 2.3158199999999995, 2.49396, 2.6721, 2.85024, 3.02838, 3.2065199999999994, 3.38466, 3.5627999999999997, 3.7409399999999997, 3.91908, 4.097219999999999, 4.27536, 4.4535, 4.631639999999999, 4.80978, 4.98792, 5.16606, 5.3442, 5.522339999999999], "y": [91.56674494842974, 91.17236320241344, 90.96010692852391, 89.98379742662715, 87.65238315617106, 85.37986305620228, 83.57541055086662, 82.2465763585866, 81.24472526479283, 80.38841692615797, 79.60881113243067, 78.8454532754977, 78.09867892225127, 77.44652568893665, 76.76827659660044, 76.05433541500993, 74.94716306133947, 74.50047626972736, 73.62712439120438, 72.68130995584951, 71.6097821301065, 70.33913130656191, 68.00137279863661, 67.18284191707376, 64.22267948625853, 59.49251658258332, 0.0, null, null, null, 0.0]}, {"legendgroup": "ts_sub", "line": {"color": "#FF5555"}, "name": "Traditional Two Stage", "showlegend": false, "type": "scatter", "x": [0.17814, 0.35628, 0.53442, 0.71256, 0.8906999999999999, 1.06884, 1.24698, 1.42512, 1.6032599999999997, 1.7813999999999999, 1.95954, 2.13768, 2.3158199999999995, 2.49396, 2.6721, 2.85024, 3.02838, 3.2065199999999994, 3.38466, 3.5627999999999997, 3.7409399999999997, 3.91908, 4.097219999999999, 4.27536, 4.4535, 4.631639999999999, 4.80978, 4.98792, 5.16606, 5.3442, 5.522339999999999], "y": [82.9810890394778, 82.74305890740179, 82.65082408915347, 78.69275341483765, 72.35320113842837, 63.686369741342176, 57.0076404859777, 43.73251625965073, 0.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null]}, {"legendgroup": "os_best", "line": {"color": "#76D1F4"}, "name": "Best One Stage", "showlegend": false, "type": "scatter", "x": [0.17814, 0.35628, 0.53442, 0.71256, 0.8906999999999999, 1.06884, 1.24698, 1.42512, 1.6032599999999997, 1.7813999999999999, 1.95954, 2.13768, 2.3158199999999995, 2.49396, 2.6721, 2.85024, 3.02838, 3.2065199999999994, 3.38466, 3.5627999999999997, 3.7409399999999997, 3.91908, 4.097219999999999, 4.27536, 4.4535, 4.631639999999999, 4.80978, 4.98792, 5.16606, 5.3442, 5.522339999999999], "y": [85.58393355530171, 84.8015016106171, 84.40590773533683, 83.37247599355676, 82.16471193483211, 81.11902318722201, 80.12846856987956, 79.12822105412319, 78.07088858224654, 76.91687934022852, 75.63346871583822, 74.16147963309538, 72.44139660252134, 70.37908784055368, 67.76579001941147, 64.10317073112665, 55.80840287166426, 0.0, null, null, null, null, null, null, null, null, null, null, null, null]}],
#                         {"height": 400, "margin": {"l": 8}, "template": {"data": {"scatter": [{"type": "scatter"}]}}, "width": 365, "xaxis": {"automargin": true, "linecolor": "black", "linewidth": 1, "mirror": true, "nticks": 10, "showline": true, "tickfont": {"color": "black", "size": 18}, "ticks": "outside", "title": {"font": {"color": "black", "size": 18}, "standoff": 0, "text": "Min Yield (% Max)"}, "zeroline": false}, "yaxis": {"automargin": true, "linecolor": "black", "linewidth": 1, "mirror": true, "range": [0, 100], "showline": true, "tickfont": {"color": "black", "size": 18}, "ticks": "outside", "title": {"font": {"color": "black", "size": 18}, "standoff": 0, "text": "Yield (% Max)"}, "zeroline": false}},
#                         {"responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('ef7755fc-9d66-4270-a2d2-296f0f599bb1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
